# %%
# %matplotlib inline
import numpy  as np
import matplotlib.pyplot as plt
X=np.array([[6],[8],[10],[14],[18]]).reshape(-1,1)
Y=[7,9,13,17.5,18]
plt.figure()
plt.title("pizza")
plt.xlabel(' Diameter in inches') 
plt.ylabel(' Price in dollars') 
plt.plot( X, Y, 'k.') 
plt.axis([ 0, 25, 0, 25]) 
plt.grid( True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X,Y)
test_valuse=np.array([[12]])
predict_valuse=model.predict(test_valuse)
#print(predict_valuse)
print('the price is  %.2f'%predict_valuse)
print(model.coef_)
# Out:
# the price is  13.68
# [ 0.9762931]

# %%
from sklearn import datasets
datasets.get_data_home()
datasets.
# Out:
# 'C:\\Users\\chenfenghui\\scikit_learn_data'

# %%
import numpy as np
x=np.array([[1],[2],[3],[4]]) 
x_mean=x.mean()
x_var=((x-x_mean)**2).sum()/(x.shape[0]-1)  #方差

print(var)
print(x_var)
print(np.var(x,ddof=1))  #numpy内置方差函数
# Out:
# 2.5
# 1.66666666667
# 1.66666666667

# %%
x.shape[0]
# Out:
# 4

# %%
import numpy as np
x=np.array([[1],[2],[3],[4]])
y=np.array([[2],[4],[7],[9]])
x_mean=x.mean()
y_mean=y.mean()
x_var=((x-x_mean)**2).sum()/(x.shape[0]-1)
x_y_cov=((x-x_mean)*(y-y_mean)/(x.shape[0]-1)).sum() #协方差
print(x_y_cov)
ten
# Out:
# 4.0

# %%
import numpy as np
import matplotlib.pyplot as plt
x_train=np.array([[158, 64], [170, 86], [183, 84], [191, 80], [155, 49], [163, 59], [180, 67], [158, 54], [170, 67]])
y_train = ['male', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'female']
plt.figure()
plt.title('human height and weight by sex')
plt.xlabel("height in cm")
plt.ylabel("weight in kg")
for i,x in enumerate(x_train):
    plt.scatter(x[0],x[1],c='k',marker="x"  if y_train[i]== 'male' else 'D')
    plt.grid(True)
    plt.show()

# %%
import numpy as np
x=np.array([[150,70]])
distinces=np.sqrt(np.sum((x_train-x)**2,axis=1)) #axis＝0表示按列相加，axis＝1表示按照行的方向相加
print(distinces)
# Out:
# [ 10.          25.61249695  35.84689666  42.20189569  21.58703314
#   17.02938637  30.14962686  17.88854382  20.22374842]

# %%
nearest_neighbor_indices = distinces.argsort()[: 3] 
nearest_neighbor_genders = np.take(y_train, nearest_neighbor_indices)
nearest_neighbor_genders
# Out:
# array(['male', 'female', 'female'],
#       dtype='<U6')

# %%
print(distinces.argsort()[: 3])
# Out:
# [0 5 7]

# %%
distinces.argsort()[: 3]
# Out:
# array([0, 5, 7], dtype=int64)

# %%
from sklearn.preprocessing import LabelBinarizer
from sklearn.neighbors import   KNeighborsClassifier
lb=LabelBinarizer()
y_train_binarized=lb.fit_transform(y_train)
print(y_train,y_train_binarized)
print(lb.inverse_transform(y_train_binarized))


K=3
clf=KNeighborsClassifier(n_neighbors=K)
clf.fit(x_train,y_train_binarized.reshape(-1))
prediction_binarized=clf.predict(np.array([155,70]).reshape(1,-1))[0]
predicted_label=lb.inverse_transform(prediction_binarized)
print(predicted_label)
# Out:
# ['male', 'male', 'male', 'male', 'female', 'female', 'female', 'female', 'female'] [[1]
#  [1]
#  [1]
#  [1]
#  [0]
#  [0]
#  [0]
#  [0]
#  [0]]
# ['male' 'male' 'male' 'male' 'female' 'female' 'female' 'female' 'female']
# ['female']

# %%
from sklearn.preprocessing import 
X_test = np.array([ [168, 65], [180, 96],[160, 52], [169, 67] ])
y_test = [' male', 'male', 'female', 'female']
y_test_binarized=lb.transform(X_test)
print()
